# %%
import robotic as ry
import numpy as np
import time

# %%
config = ry.Config()
config.addFile("puzzles/p6-wall.g")

config.view()
f = config.getFrame('camera_top')
config.view_setCamera(f)

# %%
EGO_NAME = "ego"
OBJ_NAME = "obj"
SUB_GOAL_NAME = "sub-goal1"
GOAL_NAME = "goal"
FLOOR_NAME = "floor"

GAP = config.getFrame(EGO_NAME).getSize()[1] * 2

# %%
# manually set the sub goal position
config.getFrame(SUB_GOAL_NAME).setPosition([-1.75, -1.2, 0.2])

# %%
def cartesian_to_polar(coordinates):
    x = coordinates[0]
    y = coordinates[1]
    r = np.hypot(x, y)
    theta = np.arctan2(y, x)
    return r, theta

# %%
def polar_to_cartesian(coordinates):
    r = coordinates[0]
    theta = coordinates[1]
    x = r * np.cos(theta)
    y = r * np.sin(theta)
    return x, y

# %%
def solve_touch_with_komo():
    komo = ry.KOMO(config, phases=1, slicesPerPhase=1, kOrder=0, enableCollisions=True)
    komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq, scale=[1e1])
    komo.addObjective([], ry.FS.negDistance, [EGO_NAME, OBJ_NAME], ry.OT.eq, [1e1])
    ret = ry.NLP_Solver(komo.nlp(), verbose=3).solve()
    if ret:
        path = komo.getPath()
        return path
    else:
        return None

# %%
ry.params_clear()
ry.params_add({
    "rrt/stepsize": 0.05,
    "rrt/verbose": 2
})

def solve_rrt(q_begin, q_mid, q_target):
    ITERATIONS = 24
    delta_theta = 2 * np.pi / ITERATIONS
    for i in range(ITERATIONS):
        transpose_polar1 = np.array([GAP, i * delta_theta])
        transpose_cartesian1 = np.array(polar_to_cartesian(transpose_polar1))
        q_home1 = q_mid + transpose_cartesian1
        config.setJointState(q_home1)
        # config.view(pause=True)
        q_sub = solve_touch_with_komo()
        if q_sub is not None:
            config.setJointState(q_begin)
            rrt = ry.PathFinder()
            rrt.setProblem(config, [q_begin], [q_sub])
            solution1 = rrt.solve()
            del rrt
            
            config.setJointState(q_sub)
            config.attach(EGO_NAME, OBJ_NAME)
            q_real_goal = q_target + q_sub - q_mid

            rrt = ry.PathFinder()
            rrt.setProblem(config, [q_sub], [q_real_goal])
            solution2 = rrt.solve()
            config.attach(FLOOR_NAME, OBJ_NAME)
            config.setJointState(q_begin)
            config.view()
            if solution1.feasible and solution2.feasible:
                return q_sub, solution1, solution2

    config.setJointState(q_begin)            
    return None, None, None

# %%
q_start = config.getFrame(EGO_NAME).getPosition()[:2]
q_obj = config.getFrame(OBJ_NAME).getPosition()[:2]
q_subgoal = config.getFrame(SUB_GOAL_NAME).getPosition()[:2]
q_goal = config.getFrame(GOAL_NAME).getPosition()[:2]

# %%
# move the object from start to the subgoal
q_contact1, solution1, solution2 = solve_rrt(q_start, q_obj, q_subgoal)

for state in solution1.x:
    prev_state = state

    config.setJointState(state)
    config.view()
    config.view_savePng("temp/p6-wall-p1-")
    time.sleep(3./solution1.x.shape[0])

config.attach(EGO_NAME, OBJ_NAME)

for state in solution2.x:
    prev_state = state

    config.setJointState(state)
    config.view()
    config.view_savePng("temp/p6-wall-p2-")
    time.sleep(3./solution2.x.shape[0])

config.attach(FLOOR_NAME, OBJ_NAME)
# Out:
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):0.275759 alpha:1 beta:1
# --newton-- it:   1  |Delta|:  0.0522515  alpha:          1  evals:   2  f(y):6.82555e-06  ACCEPT
# --newton-- it:   2  |Delta|:0.000259958 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   2  A(x):6.82555e-06  f:          0  g:          0  h: 0.00261257  |x-x'|:  0.0522515 	stop:DeltaConverge 	x:[-0.549739, -1.50968]
# ==nlp== it:   1  evals:   2  A(x):4.77788e-05  mu:5 	lambda:[0, -0.00522515]
# --newton-- it:   3  |Delta|:0.000313196 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   2  A(x):4.77788e-05  f:          0  g:          0  h: 0.00261257  |x-x'|:          0 	stop:DeltaConverge 	x:[-0.549739, -1.50968]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):4.77788e-05
#   -- rrt success: queries:7100 tree sizes: 410 153
#   path-length=142
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):0.399456 alpha:1 beta:1
# --newton-- it:   1  |Delta|:  0.0600003  alpha:          1  evals:   2  f(y):9.88727e-06  ACCEPT
# --newton-- it:   2  |Delta|:0.000298509 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   2  A(x):9.88727e-06  f:          0  g:          0  h: 0.00394191  |x-x'|:  0.0600003 	stop:DeltaConverge 	x:[-0.549906, -1.4497]
# ==nlp== it:   1  evals:   2  A(x):6.92109e-05  mu:5 	lambda:[0.00600003, -0.0018838]
# --newton-- it:   3  |Delta|:0.000359642 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   2  A(x):6.92109e-05  f:          0  g:          0  h: 0.00394191  |x-x'|:          0 	stop:DeltaConverge 	x:[-0.549906, -1.4497]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):6.92109e-05
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
#   -- rrt success: queries:2496 tree sizes: 278 103
#   path-length=133
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):4.00654 alpha:1 beta:1
# --newton-- it:   1  |Delta|:  0.0078474  alpha:          1  evals:   2  f(y):          4  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:   2  A(x):          4  f:          0  g:          0  h:     2.0004  |x-x'|:  0.0078474 	stop:DeltaConverge 	x:[-0.564643, -1.29231]
# ==nlp== it:   1  evals:   2  A(x):         28  mu:5 	lambda:[4, -0.000804444]
# --newton-- it:   2  |Delta|:4.70374e-05 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   2  A(x):         28  f:          0  g:          0  h:     2.0004  |x-x'|:          0 	stop:DeltaConverge 	x:[-0.564643, -1.29231]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):28
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):4.00172 alpha:1 beta:1
# --newton-- it:   1  |Delta|: 0.00343405  alpha:          1  evals:   2  f(y):          4  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:   2  A(x):          4  f:          0  g:          0  h:    2.00021  |x-x'|: 0.00343405 	stop:DeltaConverge 	x:[-0.621678, -1.20865]
# ==nlp== it:   1  evals:   2  A(x):         28  mu:5 	lambda:[4, -0.000413008]
# --newton-- it:   2  |Delta|:2.05837e-05 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   2  A(x):         28  f:          0  g:          0  h:    2.00021  |x-x'|:          0 	stop:DeltaConverge 	x:[-0.621678, -1.20865]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):28
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):4.10694 alpha:1 beta:1
# --newton-- it:   1  |Delta|:   0.100416  alpha:          1  evals:   2  f(y):    2.35187  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):     2.0053  ACCEPT
# --newton-- it:   3  |Delta|:  0.0051331  alpha:          1  evals:   4  f(y):          2  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:   4  A(x):          2  f:          0  g:          0  h:          2  |x-x'|:   0.180027 	stop:DeltaConverge 	x:[-0.874623, -1.04999]
# ==nlp== it:   1  evals:   4  A(x):         14  mu:5 	lambda:[1.99974, -2.00026]
# --newton-- it:   4  |Delta|:1.53916e-05 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   4  A(x):         14  f:          0  g:          0  h:          2  |x-x'|:          0 	stop:DeltaConverge 	x:[-0.874623, -1.04999]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):14
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):4.21251 alpha:1 beta:1
# --newton-- it:   1  |Delta|:  0.0458694  alpha:          1  evals:   2  f(y):    4.00001  ACCEPT
# --newton-- it:   2  |Delta|:0.000228206 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   2  A(x):    4.00001  f:          0  g:          0  h:    2.00229  |x-x'|:  0.0458694 	stop:DeltaConverge 	x:[-0.784813, -1.14977]
# ==nlp== it:   1  evals:   2  A(x):         28  mu:5 	lambda:[4, -0.00458694]
# --newton-- it:   3  |Delta|:0.000274941 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   2  A(x):         28  f:          0  g:          0  h:    2.00229  |x-x'|:          0 	stop:DeltaConverge 	x:[-0.784813, -1.14977]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):28
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):4.26538 alpha:1 beta:1
# --newton-- it:   1  |Delta|:  0.0512587  alpha:          1  evals:   2  f(y):    4.00001  ACCEPT
# --newton-- it:   2  |Delta|:0.000255018 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   2  A(x):    4.00001  f:          0  g:          0  h:    2.00256  |x-x'|:  0.0512587 	stop:DeltaConverge 	x:[-0.91481, -1.14974]
# ==nlp== it:   1  evals:   2  A(x):         28  mu:5 	lambda:[4, -0.00512587]
# --newton-- it:   3  |Delta|:0.000307245 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   2  A(x):         28  f:          0  g:          0  h:    2.00256  |x-x'|:          0 	stop:DeltaConverge 	x:[-0.91481, -1.14974]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):28
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):40.8839 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    23.2212  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    14.3636  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    2.41548  ACCEPT
# --newton-- it:   4  |Delta|:   0.154645  alpha:          1  evals:   5  f(y):5.97876e-05  ACCEPT
# --newton-- it:   5  |Delta|:0.000769378 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   5  A(x):5.97876e-05  f:          0  g:          0  h: 0.00773225  |x-x'|:   0.353206 	stop:DeltaConverge 	x:[-1.25077, -1.47382]
# ==nlp== it:   1  evals:   5  A(x):0.000418514  mu:5 	lambda:[0, -0.0154645]
# --newton-- it:   6  |Delta|:0.000926943 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   5  A(x):0.000418514  f:          0  g:          0  h: 0.00773225  |x-x'|:          0 	stop:DeltaConverge 	x:[-1.25077, -1.47382]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):0.000418514
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):39.7721 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    20.9887  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    2.82456  ACCEPT
# --newton-- it:   3  |Delta|:   0.158656  alpha:          1  evals:   4  f(y):6.99131e-05  ACCEPT
# --newton-- it:   4  |Delta|:0.000789335 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   4  A(x):6.99131e-05  f:          0  g:          0  h:  0.0105754  |x-x'|:   0.294999 	stop:DeltaConverge 	x:[-1.25079, -1.44974]
# ==nlp== it:   1  evals:   4  A(x):0.000489392  mu:5 	lambda:[0.00528524, -0.0158656]
# --newton-- it:   5  |Delta|:0.000950988 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   4  A(x):0.000489392  f:          0  g:          0  h:  0.0105754  |x-x'|:          0 	stop:DeltaConverge 	x:[-1.25079, -1.44974]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):0.000489392
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):30.6711 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):   0.740913  ACCEPT
# --newton-- it:   2  |Delta|:  0.0800148  alpha:          1  evals:   3  f(y): 1.8339e-05  ACCEPT
# --newton-- it:   3  |Delta|:0.000398084 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   3  A(x): 1.8339e-05  f:          0  g:          0  h: 0.00552817  |x-x'|:   0.230548 	stop:DeltaConverge 	x:[-1.2504, -1.44985]
# ==nlp== it:   1  evals:   3  A(x):0.000128373  mu:5 	lambda:[0.00305485, -0.00800148]
# --newton-- it:   4  |Delta|:0.000479609 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   3  A(x):0.000128373  f:          0  g:          0  h: 0.00552817  |x-x'|:          0 	stop:DeltaConverge 	x:[-1.2504, -1.44985]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):0.000128373
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):20.1094 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):   0.366467  ACCEPT
# --newton-- it:   2  |Delta|:  0.0602354  alpha:          1  evals:   3  f(y):9.07074e-06  ACCEPT
# --newton-- it:   3  |Delta|:0.000299678 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   3  A(x):9.07074e-06  f:          0  g:          0  h: 0.00301177  |x-x'|:        0.2 	stop:DeltaConverge 	x:[-1.2503, -1.49019]
# ==nlp== it:   1  evals:   3  A(x):6.34952e-05  mu:5 	lambda:[0, -0.00602354]
# --newton-- it:   4  |Delta|:0.000361051 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   3  A(x):6.34952e-05  f:          0  g:          0  h: 0.00301177  |x-x'|:          0 	stop:DeltaConverge 	x:[-1.2503, -1.49019]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):6.34952e-05
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):0.386001 alpha:1 beta:1
# --newton-- it:   1  |Delta|:  0.0451585  alpha:          1  evals:   2  f(y):9.55424e-06  ACCEPT
# --newton-- it:   2  |Delta|:0.000224669 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   2  A(x):9.55424e-06  f:          0  g:          0  h: 0.00436885  |x-x'|:  0.0451585 	stop:DeltaConverge 	x:[-1.25021, -1.44977]
# ==nlp== it:   1  evals:   2  A(x):6.68797e-05  mu:5 	lambda:[0.00451585, -0.00422185]
# --newton-- it:   3  |Delta|: 0.00027068 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   2  A(x):6.68797e-05  f:          0  g:          0  h: 0.00436885  |x-x'|:          0 	stop:DeltaConverge 	x:[-1.25021, -1.44977]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):6.68797e-05
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):0.370408 alpha:1 beta:1
# --newton-- it:   1  |Delta|:  0.0605584  alpha:          1  evals:   2  f(y):9.16829e-06  ACCEPT
# --newton-- it:   2  |Delta|:0.000301285 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   2  A(x):9.16829e-06  f:          0  g:          0  h: 0.00302792  |x-x'|:  0.0605584 	stop:DeltaConverge 	x:[-1.2503, -1.49777]
# ==nlp== it:   1  evals:   2  A(x): 6.4178e-05  mu:5 	lambda:[0, -0.00605584]
# --newton-- it:   3  |Delta|:0.000362987 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   2  A(x): 6.4178e-05  f:          0  g:          0  h: 0.00302792  |x-x'|:          0 	stop:DeltaConverge 	x:[-1.2503, -1.49777]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):6.4178e-05
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):0.198382 alpha:1 beta:1
# --newton-- it:   1  |Delta|:  0.0443185  alpha:          1  evals:   2  f(y):4.91032e-06  ACCEPT
# --newton-- it:   2  |Delta|: 0.00022049 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   2  A(x):4.91032e-06  f:          0  g:          0  h: 0.00221592  |x-x'|:  0.0443185 	stop:DeltaConverge 	x:[-1.25022, -1.61237]
# ==nlp== it:   1  evals:   2  A(x):3.43722e-05  mu:5 	lambda:[0, -0.00443185]
# --newton-- it:   3  |Delta|:0.000265645 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   2  A(x):3.43722e-05  f:          0  g:          0  h: 0.00221592  |x-x'|:          0 	stop:DeltaConverge 	x:[-1.25022, -1.61237]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):3.43722e-05
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):0.00897484 alpha:1 beta:1
# --newton-- it:   1  |Delta|: 0.00655372  alpha:          1  evals:   2  f(y):5.58133e-08  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:   2  A(x):5.58133e-08  f:          0  g:          0  h:0.000334106  |x-x'|: 0.00655372 	stop:DeltaConverge 	x:[-1.23698, -1.69932]
# ==nlp== it:   1  evals:   2  A(x):3.90693e-07  mu:5 	lambda:[0.000334106, 0.000334106]
# --newton-- it:   2  |Delta|:1.96513e-05 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   2  A(x):3.90693e-07  f:          0  g:          0  h:0.000334106  |x-x'|:          0 	stop:DeltaConverge 	x:[-1.23698, -1.69932]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):3.90693e-07
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):0.480986 alpha:1 beta:1
# --newton-- it:   1  |Delta|:  0.0366944  alpha:          1  evals:   2  f(y):  0.0069692  ACCEPT
# --newton-- it:   2  |Delta|:   0.009933  alpha:          1  evals:   3  f(y):3.56787e-07  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:   3  A(x):3.56787e-07  f:          0  g:          0  h:0.000597316  |x-x'|:  0.0330522 	stop:DeltaConverge 	x:[-1.21033, -1.74999]
# ==nlp== it:   1  evals:   3  A(x):2.49751e-06  mu:5 	lambda:[0, -0.00119463]
# --newton-- it:   3  |Delta|:5.95385e-05 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   3  A(x):2.49751e-06  f:          0  g:          0  h:0.000597316  |x-x'|:          0 	stop:DeltaConverge 	x:[-1.21033, -1.74999]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):2.49751e-06
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):2.84356 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    1.67075  ACCEPT
# --newton-- it:   2  |Delta|:  0.0896219  alpha:          1  evals:   3  f(y):2.90453e-05  ACCEPT
# --newton-- it:   3  |Delta|: 0.00044588 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   3  A(x):2.90453e-05  f:          0  g:          0  h: 0.00538937  |x-x'|:   0.110378 	stop:DeltaConverge 	x:[-1.21091, -1.74998]
# ==nlp== it:   1  evals:   3  A(x):0.000203317  mu:5 	lambda:[0, -0.0107787]
# --newton-- it:   4  |Delta|:0.000537194 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   3  A(x):0.000203317  f:          0  g:          0  h: 0.00538937  |x-x'|:          0 	stop:DeltaConverge 	x:[-1.21091, -1.74998]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):0.000203317
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):7.96159 alpha:1 beta:1
# --newton-- it:   1  |Delta|:    0.11956  alpha:          1  evals:   2  f(y):    2.08096  ACCEPT
# --newton-- it:   2  |Delta|:  0.0200694  alpha:          1  evals:   3  f(y):    2.10878  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:   4  f(y):    2.13704  reject (lineSearch:1)
#                     (line search)        alpha:       0.25  evals:   5  f(y):    2.04562  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:   5  A(x):    2.04562  f:          0  g:          0  h:          2  |x-x'|:   0.124577 	stop:DeltaConverge 	x:[-1.01034, -1.7651]
# ==nlp== it:   1  evals:   5  A(x):    14.3193  mu:5 	lambda:[2.30204, 1.69796]
# --newton-- it:   3  |Delta|:  0.0181136  alpha:      0.375  evals:   6  f(y):    14.8094  reject (lineSearch:0)
#                     (line search)        alpha:     0.1875  evals:   7  f(y):     14.914  reject (lineSearch:1)
#                     (line search)        alpha:    0.09375  evals:   8  f(y):    14.2606  ACCEPT
# --newton-- it:   4  |Delta|:  0.0164163  alpha:   0.140625  evals:   9  f(y):    14.8935  reject (lineSearch:0)
#                     (line search)        alpha:  0.0703125  evals:  10  f(y):    14.9328  reject (lineSearch:1)
#                     (line search)        alpha:  0.0351562  evals:  11  f(y):    14.9535  reject (lineSearch:2)
#                     (line search)        alpha:  0.0175781  evals:  12  f(y):    14.9641  reject (lineSearch:3)
#                     (line search)        alpha: 0.00878906  evals:  13  f(y):    14.2559  ACCEPT
# --newton-- it:   5  |Delta|:  0.0162721  alpha:  0.0131836  evals:  14  f(y):    14.9615  reject (lineSearch:0)
#                     (line search)        alpha:  0.0065918  evals:  15  f(y):    14.2524  ACCEPT
# --newton-- it:   6  |Delta|:  0.0161649  alpha:  0.0098877  evals:  16  f(y):    14.9596  reject (lineSearch:0)
#                     (line search)        alpha: 0.00494385  evals:  17  f(y):    14.9625  reject (lineSearch:1)
#                     (line search)        alpha: 0.00247192  evals:  18  f(y):     14.964  reject (lineSearch:2)
#                     (line search)        alpha: 0.00123596  evals:  19  f(y):    14.2518  ACCEPT
# --newton-- it:   7  |Delta|:  0.0161449  alpha: 0.00185394  evals:  20  f(y):    14.9636  reject (lineSearch:0)
#                     (line search)        alpha:0.000926971  evals:  21  f(y):    14.9642  reject (lineSearch:1)
#                     (line search)        alpha:0.000463486  evals:  22  f(y):    14.2516  ACCEPT
# --newton-- it:   8  |Delta|:  0.0161374  alpha:0.000695229  evals:  23  f(y):    14.9641  reject (lineSearch:0)
#                     (line search)        alpha:0.000347614  evals:  24  f(y):    14.9643  reject (lineSearch:1)
#                     (line search)        alpha:0.000173807  evals:  25  f(y):    14.2515  ACCEPT
# --newton-- it:   9  |Delta|:  0.0161346  alpha:0.000260711  evals:  26  f(y):    14.9642  reject (lineSearch:0)
#                     (line search)        alpha:0.000130355  evals:  27  f(y):    14.2514  ACCEPT
# --newton-- it:  10  |Delta|:  0.0161325  alpha:0.000195533  evals:  28  f(y):    14.9642  reject (lineSearch:0)
#                     (line search)        alpha:9.77665e-05  evals:  29  f(y):    14.9642  reject (lineSearch:1)
#                     (line search)        alpha:4.88833e-05  evals:  30  f(y):    14.9643  reject (lineSearch:2)
#                     (line search)        alpha:2.44416e-05  evals:  31  f(y):    14.9643  reject (lineSearch:3)
#                     (line search)        alpha:1.22208e-05  evals:  32  f(y):    14.2514  ACCEPT
# --newton-- stopping: 'numTinyXSteps>4'
# ==nlp== it:   1  evals:  32  A(x):    14.2514  f:          0  g:          0  h:          2  |x-x'|: 0.00198226 	stop:TinyXSteps (bad:1) 	x:[-1.01034, -1.76312]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):14.2514
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_right) [16,9] 	d=-0
# proxy:  (ego)-(outwall_right) [16,2] 	d=-0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):9.25425 alpha:1 beta:1
# --newton-- it:   1  |Delta|:   0.129903  alpha:          1  evals:   2  f(y):    2.08104  ACCEPT
# --newton-- it:   2  |Delta|:  0.0200797  alpha:          1  evals:   3  f(y):          2  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:   3  A(x):          2  f:          0  g:          0  h:          2  |x-x'|:   0.149982 	stop:DeltaConverge 	x:[-0.915125, -1.75005]
# ==nlp== it:   1  evals:   3  A(x):         14  mu:5 	lambda:[2.001, 1.999]
# --newton-- it:   3  |Delta|: 6.0209e-05 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   3  A(x):         14  f:          0  g:          0  h:          2  |x-x'|:          0 	stop:DeltaConverge 	x:[-0.915125, -1.75005]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):14
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_right) [16,9] 	d=-0
# proxy:  (ego)-(outwall_right) [16,2] 	d=-0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_front) [16,5] 	d=-0
# proxy:  (ego)-(outwall_front) [16,12] 	d=-0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):7.54927 alpha:1 beta:1
# --newton-- it:   1  |Delta|:   0.116067  alpha:          1  evals:   2  f(y):    2.08093  ACCEPT
# --newton-- it:   2  |Delta|:  0.0200659  alpha:          1  evals:   3  f(y):          2  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:   3  A(x):          2  f:          0  g:          0  h:          2  |x-x'|:   0.136133 	stop:DeltaConverge 	x:[-0.804449, -1.75005]
# ==nlp== it:   1  evals:   3  A(x):         14  mu:5 	lambda:[2.001, 1.999]
# --newton-- it:   3  |Delta|:6.01676e-05 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   3  A(x):         14  f:          0  g:          0  h:          2  |x-x'|:          0 	stop:DeltaConverge 	x:[-0.804449, -1.75005]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):14
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (ego)-(outwall_right) [16,9] 	d=-0
# proxy:  (ego)-(outwall_right) [16,2] 	d=-0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):4.13561 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    2.06694  ACCEPT
# --newton-- it:   2  |Delta|:  0.0969982  alpha:          1  evals:   3  f(y): 3.4023e-05  ACCEPT
# --newton-- it:   3  |Delta|:0.000482578 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   3  A(x): 3.4023e-05  f:          0  g:          0  h: 0.00583292  |x-x'|:   0.103002 	stop:DeltaConverge 	x:[-0.589034, -1.74998]
# ==nlp== it:   1  evals:   3  A(x):0.000238161  mu:5 	lambda:[0, -0.0116658]
# --newton-- it:   4  |Delta|:0.000581408 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   3  A(x):0.000238161  f:          0  g:          0  h: 0.00583292  |x-x'|:          0 	stop:DeltaConverge 	x:[-0.589034, -1.74998]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):0.000238161
#   -- rrt success: queries:2855 tree sizes: 306 78
#   path-length=133
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
#   -- rrt success: queries:443 tree sizes: 37 11
#   path-length=26

# %%
q_agent = config.getFrame(EGO_NAME).getPosition()[:2]
q_obj = config.getFrame(OBJ_NAME).getPosition()[:2]

# %%
# move the object from subgoal to the goal
q_contact2, solution3, solution4 = solve_rrt(q_agent, q_obj, q_goal)

for state in solution3.x:
    prev_state = state

    config.setJointState(state)
    config.view()
    config.view_savePng("temp/p6-wall-p3-")
    time.sleep(3./solution3.x.shape[0])

config.attach(EGO_NAME, OBJ_NAME)

for state in solution4.x:
    prev_state = state

    config.setJointState(state)
    config.view()
    config.view_savePng("temp/p6-wall-p4-")
    time.sleep(3./solution4.x.shape[0])
# Out:
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):16.1546 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):     14.532  ACCEPT
# --newton-- it:   2  |Delta|:   0.150311  alpha:          1  evals:   3  f(y):    12.2501  ACCEPT
# --newton-- it:   3  |Delta|:0.000747814 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   3  A(x):    12.2501  f:          0  g:          0  h:    3.50752  |x-x'|:  0.0496893 	stop:DeltaConverge 	x:[-1.40075, -1.20025]
# ==nlp== it:   1  evals:   3  A(x):    85.7504  mu:5 	lambda:[7, 0.0150311]
# --newton-- it:   4  |Delta|:0.000900963 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   3  A(x):    85.7504  f:          0  g:          0  h:    3.50752  |x-x'|:          0 	stop:DeltaConverge 	x:[-1.40075, -1.20025]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):85.7504
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (wall2_h)-(ego) [19,16] 	d=-0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# -- RRT_PathFinder.cpp:RRT_PathFinder:258(0) initializing with infeasible qT:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
# proxy:  (obj)-(ego) [21,16] 	d=-0
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1 	lambda:[]
# ----newton---- initial point f(x):9.39092 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):   0.523424  ACCEPT
# --newton-- it:   2  |Delta|:  0.0598557  alpha:          1  evals:   3  f(y):1.29557e-05  ACCEPT
# --newton-- it:   3  |Delta|:0.000297789 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   0  evals:   3  A(x):1.29557e-05  f:          0  g:          0  h:  0.0035994  |x-x'|:   0.160005 	stop:DeltaConverge 	x:[-1.44666, -0.939003]
# ==nlp== it:   1  evals:   3  A(x):  9.069e-05  mu:5 	lambda:[0, -0.00719881]
# --newton-- it:   4  |Delta|:0.000358775 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   1  evals:   3  A(x):  9.069e-05  f:          0  g:          0  h:  0.0035994  |x-x'|:          0 	stop:DeltaConverge 	x:[-1.44666, -0.939003]
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):9.069e-05
# -- RRT_PathFinder.cpp:RRT_PathFinder:257(0) initializing with infeasible q0:
# query: h_goal: 0 g_coll: 0 isGoal: 1 isFeasible: 0
#   -- rrt success: queries:3643 tree sizes: 160 329
#   path-length=178
#   -- rrt success: queries:952 tree sizes: 91 81
#   path-length=105

# %%
config.view()
# Out:
# 0

# %%
config.view_close()
del config
